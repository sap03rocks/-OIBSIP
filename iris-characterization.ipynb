# %% [markdown]
# <a href="https://www.kaggle.com/code/officialaa/iris-characterization?scriptVersionId=149387845" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt# FOR PLOTTING PURPOSES
import seaborn as sb#FOR PLOTTING DATA

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/iriscsv/Iris.csv

# %%
#loading dataset
df = pd.read_csv('/kaggle/input/iriscsv/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#Display ABOUT first 20 and last 20 rows of dataset
print("First 20 rows of dataset are: ")
print(df.head(20))
print("\n")
print("Last 20 rows of dataset are: ")
print(df.tail(20))
# Out:
# First 20 rows of dataset are:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
#Lets focus on the statistics of the dataset
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#information about the dataset by having number of entries 
#the data types of them such as integer float along with their data size
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#to know the dimentions (coloumns,row) of the dataset
dimension= df.shape
print("dimension of the dataset is:",dimension)
# Out:
# dimension of the dataset is: (150, 6)

# %%
#in order to understand which the exact number of each of the species 
each_species=df.value_counts("Species")
print("No.of flowers in each ",each_species)
# Out:
# No.of flowers in each  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
#We will construct a count plot to visually see the count of each species of the given flower dataset
sb.countplot(x='Species', data=df)
plt.show()

# %%
plt.hist(df['SepalLengthCm'],color='red')
plt.title("Sepal length vs frequency")
plt.xlabel("Sepal Length")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
plt.hist(df['PetalLengthCm'],color = 'black')
plt.title("Sepal Length vs Frequency")
plt.xlabel("Sepal Length")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
plt.hist(df['SepalWidthCm'],color='green')
plt.title("Sepal Width vs frequency")
plt.xlabel("Sepal width")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
plt.hist(df['PetalWidthCm'],color='yellow')
plt.title("petal width vs frequency")
plt.xlabel("petal width")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
sb.swarmplot(x='Species',y='SepalLengthCm',data=df)
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
#Lets understand the sepal length and sepal width relationship by using scatterplot from seaborn library 
sb.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue='Species', data=df, )
plt.show()

# %%
#Lets understand the sepal length and sepal width relationship by using scatterplot from seaborn library  
sb.scatterplot(x='PetalLengthCm', y='PetalWidthCm', hue='Species', data=df, )
plt.show()

# %%
#We will see the plot between sepallength and petal width by plotting a Scatter plot between them.
sb.scatterplot(x='SepalLengthCm', y='PetalWidthCm', hue='Species', data=df, )
plt.show()

# %%
#Multivariate analysis
#Pairplot which shows the pair-wise relation between every attributes
sb.pairplot(df,hue='Species', height=4)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#in kaggle if u are using categorical data to continuous
encoded=pd.get_dummies(df)
encoded
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#      Species_Iris-setosa  Species_Iris-versicolor  Species_Iris-virginica
# 0                   True                    False                   False
# ...

# %%
sb.heatmap(encoded.corr(), annot = True)
plt.show()

# %% [markdown]
#  ***in order to prevent our machine learning model from beign overfitting and just have 100 percent accuracy with no other data getting fitted we split the dataset into two parts the one which is training dataset which gives us the training data for our model and the testing data to predict the accuracy of the model and thus improving chances of error detectionm and so we use scikit library's test train split function***

# %%
from sklearn.model_selection import train_test_split
x = df.drop(columns = ['Species'])
y = df['Species']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.80)
y_test
# Out:
# 76     Iris-versicolor
# 74     Iris-versicolor
# 49         Iris-setosa
# 88     Iris-versicolor
# 13         Iris-setosa
#             ...
# 103     Iris-virginica
# 93     Iris-versicolor
# 117     Iris-virginica
# 114     Iris-virginica
# 121     Iris-virginica
# Name: Species, Length: 120, dtype: object

# %%
#Importing library for decision classifier
from sklearn.tree import DecisionTreeClassifier
id3=DecisionTreeClassifier(criterion='entropy')
#Fit the data
k=id3.fit(x_train,y_train)
#predict the data
y_pred=id3.predict(x_test)
print(y_pred)
# Out:
# ['Iris-virginica' 'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-virginica' 'Iris-setosa' 'Iris-setosa'
#  'Iris-virginica' 'Iris-setosa' 'Iris-virginica' 'Iris-setosa'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-setosa' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-setosa'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-setosa' 'Iris-setosa'
# ...

# %%
#Confusion matrix 
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cm=confusion_matrix(y_pred,y_test)
plt.figure(figsize=(10,8))
sb.heatmap(cm,annot=True)
plt.xlabel('predicted-y')
plt.ylabel('actual-y')
plt.show()

# %%
#Accuracy score and model score
print(classification_report(y_pred,y_test))
print('accuracy-score',accuracy_score(y_pred,y_test))
print('Model score',id3.score(x_test,y_test))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      0.90      0.95        49
# Iris-versicolor       0.73      0.97      0.83        31
#  Iris-virginica       0.97      0.85      0.91        40
#
#        accuracy                           0.90       120
#       macro avg       0.90      0.91      0.90       120
#    weighted avg       0.92      0.90      0.90       120
#
# accuracy-score 0.9
# Model score 0.9
